# %% [markdown]
# # データセットのダウンロード方法
#
# このスクリプトの実行で得られるデータは大きすぎて.gitに乗らないため、.gitignoreされているdata_downloadedというフォルダを作成し、
# 実行することがおすすめ

# %% [markdown]
# ## How to download ChEMBL dataset
#
# 「ChEMBL download」などと検索すると出てくる[このページ](https://chembl.gitbook.io/chembl-interface-documentation/downloads)を開いて"ChEMBLdb"をクリック
#
# chembl_{数字}.sdf.gzをダウンロード
#
# クリックでそのままダウンロードしても良いし、wgetでダウンロードするのもOK.
# ただしダウンロードするのに1時間弱くらい時間がかかる
# ```cmd
# wget https://ftp.ebi.ac.uk/pub/databases/chembl/ChEMBLdb/latest/chembl_33.sdf.gz
# ```

# %%
import gzip
from rdkit import Chem
# sdf.gzファイルのまま読み込む場合は以下をコメントアウト
#sdf_gz = gzip.open("./chembl_33.sdf.gz")
#sup = Chem.ForwardSDMolSupplier(sdf_gz)
#mols = [mol for mol in sup if mol is not None]
#mols

# %% [markdown]
# 以下のコマンドで元ファイルを残したままファイルを解凍することができる
# ```cmd
# gunzip -k chembl_33.sdf.gz
# ```
#
# ただし、ファイルが大きすぎるので読み込むにも時間がかかるため、```sdf_split.py```を用いてsdfファイルを分子ごとに分割することができる（が、それもまた時間がかかるしファイル容量が大きくなってしまうので注意）
# ```
# python sdf_split.py
# ```

# %% [markdown]
# ## How to download zinc dataset
#
# 多くの化合物を選択するとダウンロードに時間がかかる（場合によってはできない）ので、subsetを適当に選択する。
#
# 例1)世界で承認されている(多分)化合物のデータセット
# https://zinc15.docking.org/substances/subsets/world/
#
# 例2)今すぐ買うことができる化合物のデータセット
# https://zinc15.docking.org/substances/subsets/now/
#
# 左上の方に下矢印のボタンが出てくるので、そこを押すと好きなフォーマットでダウンロードすることができる。
#
# 以上のリンクの最後に好きなフォーマットをつけてwgetでダウンロードすることも可能
#
# ```cmd
# wget https://zinc15.docking.org/substances/subsets/now.sdf
# ```

# %%
from rdkit import Chem
from rdkit.Chem import Draw

suppl = Chem.SDMolSupplier("./data_downloaded/now.sdf")
mols = [x for x in suppl if x is not None] #./now.sdfに含まれる分子をmolオブジェクトにしたもののリスト

print(len(mols))
# Out:
# 100

# %%
# get property name

for prop in mols[0].GetPropNames():
     print('{}: {}'.format(prop, mols[0].GetProp(prop)))
# Out:
# zinc_id: ZINC000953998451
# smiles: COc1cc2cc(c1Cl)N(C)C(=O)C[C@H](OC(=O)[C@H](C)N(C)C(=O)CCC(C)(C)S)[C@]1(C)O[C@H]1[C@H](C)[C@@H]1C[C@@](O)(NC(=O)O1)[C@H](OC)C=CC=C(C)C2

# %%
Draw.MolsToGridImage(mols[:60], 
                     molsPerRow = 5, #1行あたりに表示する分子数
                     subImgSize = (150,150), #画像の大きさ
                     legends = [mol.GetProp("zinc_id") for mol in mols], #凡例
                     maxMols = 60) #表示する最大分子数

# %%
# pandastoolを用いた解析手法
import pandas as pd
from rdkit.Chem import PandasTools

df = PandasTools.LoadSDF('./data_downloaded/now.sdf')
df.head
# Out:
# <bound method NDFrame.head of              zinc_id                                             smiles ID  \
# 0   ZINC000953998451  COc1cc2cc(c1Cl)N(C)C(=O)C[C@H](OC(=O)[C@H](C)N...
# 1   ZINC000953033979  COC(=O)[C@@H]1C[C@@H](O[Si](c2ccccc2)(c2ccccc2...
# 2   ZINC000953009923  CC[C@@H](C)N1c2ccccc2C(=O)N(C)c2cnc(Nc3ccc(C(=...
# 3   ZINC000694950226                         NC(=O)c1cccc(C(F)(F)F)c1Br
# 4   ZINC000689670529                    O=[N+]([O-])c1cccn2c1nc1ccccc12
# ..               ...                                                ... ..
# 95  ZINC000147832037                               COc1cc(C)nc(OC)c1C#N
# 96  ZINC000224309252  Nc1ccc(C(=O)Nc2cccc(Nc3ncc(Cl)c(-c4cn(S(=O)(=O...
# 97  ZINC000224188557  CC(C)(C)P1c2c(cccc2-c2c3ccccc3cc3ccccc23)O[C@H...
# 98  ZINC000147540753                         CCOC(=O)N(CC(=O)O)Cc1ccco1
# 99  ZINC000147242206  O=C1OC2(c3ccc(OS(=O)(=O)C(F)(F)F)cc3Oc3cc(OS(=...
#
#                                                 ROMol
# ...

# %%
df[['zinc_id','smiles']].to_csv('./data_downloaded/now_sdf.csv',encoding='utf-8')

# %% [markdown]
# ## 薬物の特性情報を計算する方法

# %% [markdown]
# 1. QED(薬らしさ)の計算方法
#
# 参考: https://future-chem.com/rdkit-qed/

# %%
from rdkit import rdBase, Chem
from rdkit.Chem import PandasTools, QED, Descriptors, rdMolDescriptors

df = PandasTools.LoadSDF("./data_downloaded/now.sdf")
len(df)
# Out:
# 100

# %%
df['QED'] = df.ROMol.map(QED.qed)
df.head
# Out:
# <bound method NDFrame.head of              zinc_id                                             smiles ID  \
# 0   ZINC000953998451  COc1cc2cc(c1Cl)N(C)C(=O)C[C@H](OC(=O)[C@H](C)N...
# 1   ZINC000953033979  COC(=O)[C@@H]1C[C@@H](O[Si](c2ccccc2)(c2ccccc2...
# 2   ZINC000953009923  CC[C@@H](C)N1c2ccccc2C(=O)N(C)c2cnc(Nc3ccc(C(=...
# 3   ZINC000694950226                         NC(=O)c1cccc(C(F)(F)F)c1Br
# 4   ZINC000689670529                    O=[N+]([O-])c1cccn2c1nc1ccccc12
# ..               ...                                                ... ..
# 95  ZINC000147832037                               COc1cc(C)nc(OC)c1C#N
# 96  ZINC000224309252  Nc1ccc(C(=O)Nc2cccc(Nc3ncc(Cl)c(-c4cn(S(=O)(=O...
# 97  ZINC000224188557  CC(C)(C)P1c2c(cccc2-c2c3ccccc3cc3ccccc23)O[C@H...
# 98  ZINC000147540753                         CCOC(=O)N(CC(=O)O)Cc1ccco1
# 99  ZINC000147242206  O=C1OC2(c3ccc(OS(=O)(=O)C(F)(F)F)cc3Oc3cc(OS(=...
#
#                                                 ROMol       QED
# ...

# %%
# 3つの重み付けパターンがある。
df['QED_weight_max'] = df.ROMol.map(QED.weights_max)
df['QED_weight_mean'] = df.ROMol.map(QED.weights_mean)
df['QED_weight_none'] = df.ROMol.map(QED.weights_none)
df[['ROMol','QED_weight_max','QED_weight_mean','QED_weight_none','QED']]
# Out:
#                                                 ROMol  QED_weight_max  \
# 0   <img data-content="rdkit/molecule" src="data:i...        0.162187
# 1   <img data-content="rdkit/molecule" src="data:i...        0.561999
# 2   <img data-content="rdkit/molecule" src="data:i...        0.449359
# 3   <img data-content="rdkit/molecule" src="data:i...        0.844133
# 4   <img data-content="rdkit/molecule" src="data:i...        0.424685
# ..                                                ...             ...
# 95  <img data-content="rdkit/molecule" src="data:i...        0.680847
# 96  <img data-content="rdkit/molecule" src="data:i...        0.228635
# 97  <img data-content="rdkit/molecule" src="data:i...        0.159813
# 98  <img data-content="rdkit/molecule" src="data:i...        0.823405
# 99  <img data-content="rdkit/molecule" src="data:i...        0.146403
#
#     QED_weight_mean  QED_weight_none       QED
# 0          0.186510         0.189835  0.186510
# ...

# %% [markdown]
# 2. ルール・オブ・ファイブ（リピンスキーの法則）
#
# 傾向バイオアベイラビリティーの優れた薬物を予測するための大まかな経験則

# %%
def rule_of_five(mol):
    mol_weight = Descriptors.MolWt(mol)
    logp = Descriptors.MolLogP(mol)
    hbd = rdMolDescriptors.CalcNumLipinskiHBD(mol)
    hba = rdMolDescriptors.CalcNumLipinskiHBA(mol)
    psa = Descriptors.TPSA(mol)

    if (mol_weight <= 500 and logp <= 5 and hbd <= 5 and hba <= 10):
        # 上の条件式に5の倍数が多く出てくるのでrule of fiveと呼ばれている
        return 1
    else:
        return 0

# %%
import matplotlib as mpl
import seaborn as sns

df['Lipinski'] = df.ROMol.map(rule_of_five)

with mpl.style.context('seaborn'):
    sns.violinplot(x='Lipinski', y='QED', data=df) #rule of fiveを通らない分子はQEDも低い傾向にある

# %% [markdown]
# 3. logP(化合物の脂溶性)

# %%
df['logP'] = df.ROMol.map(Descriptors.MolLogP)
df[['ROMol','logP']]
# Out:
#                                                 ROMol     logP
# 0   <img data-content="rdkit/molecule" src="data:i...   5.0031
# 1   <img data-content="rdkit/molecule" src="data:i...   2.4665
# 2   <img data-content="rdkit/molecule" src="data:i...   4.6074
# 3   <img data-content="rdkit/molecule" src="data:i...   2.5668
# 4   <img data-content="rdkit/molecule" src="data:i...   2.3957
# ..                                                ...      ...
# 95  <img data-content="rdkit/molecule" src="data:i...   1.2789
# 96  <img data-content="rdkit/molecule" src="data:i...   6.5668
# 97  <img data-content="rdkit/molecule" src="data:i...  13.5820
# 98  <img data-content="rdkit/molecule" src="data:i...   1.3227
# 99  <img data-content="rdkit/molecule" src="data:i...   4.7114
#
# [100 rows x 2 columns]
